# %% [markdown]
# # Aula 02: Introdução ao Python

# %% [markdown]
# ## Exibindo uma mensagem na tela

# %%
print("Salve, Mauá!")
# Out:
# Salve, Mauá!

# %% [markdown]
# ## Variáveis

# %%
mensagem = "Salve, Mauá"
print(mensagem)
# Out:
# Salve, Mauá

# %%
# Erro provocado por caixa!
mensagem = "Salve, Mauá"
print(Mensagem)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-d72021c6ba56> in <module>
#       1 mensagem = "Salve, Mauá"
# ----> 2 print(Mensagem)
#
# NameError: name 'Mensagem' is not defined

# %% [markdown]
# ## Tipos de variáveis: Strings

# %%
# Exemplos de texto
texto1 = "Exemplo 1 de strings"
texto2 = 'Exemplo 2 de strings'

print(texto1, texto2)

texto3 = 'Atenção às "aspas"'
print(texto3)
# Out:
# Exemplo 1 de strings Exemplo 2 de strings
# Atenção às "aspas"

# %%
# Modificando strings
texto1 = "Exemplo de texto!"
print(texto1.title())
print(texto1.upper())
print(texto1.lower())
print(texto1.swapcase())
# Out:
# Exemplo De Texto!
# EXEMPLO DE TEXTO!
# exemplo de texto!
# eXEMPLO DE TEXTO!

# %%
# Combinando strings
nome = "Jones"
sobrenome = "Egydio"
print(nome + sobrenome)
# Out:
# JonesEgydio

# %%
# Combinando strings
nome = "Jones"
sobrenome = "Egydio"
print(nome + " " + sobrenome)
# Out:
# Jones Egydio

# %% [markdown]
# ## Tipos de variáveis: números

# %%
# Operações com números inteiros
print(3 + 2)
print(3 - 2)
print(3 * 2)
print(3 / 2)
print(3 // 2) # divisão interia
print(5 // 2)
print(3 % 2) # resto da divisão
print(23 % 3)
print(3 ** 2)
# Out:
# 5
# 1
# 6
# 1.5
# 1
# 2
# 1
# 2
# 9

# %%
# Precedência geral dos operadores aritméticos
expressão1 = 6/2*1+2
print(expressão1)

expressão2 = 6/2*(1+2)
print(expressão2)

expressão3 = 6/(2*(1+2))
print(expressão3)
# Out:
# 5.0
# 9.0
# 1.0

# %%
# Exemplos envolvendo números reais
expressão1 = 0.1 + 0.1
print(expressão1)

expressão2 = 0.1 + 0.2
print(expressão2)

expressão3 = 0.1 + 0.2 - 0.3
print(expressão3)
# Out:
# 0.2
# 0.30000000000000004
# 5.551115123125783e-17

# %% [markdown]
# ## Marcadores

# %%
# Exemplos de substituição
x = 3.14159
y = 3.3
unid = "Hz"

print("O valor é", x, unid)
print(" ")
print("O valor é %f" %x)
print("O valor é %2f" %x)
print("O valor é %2f" %y)
print(" ")
print("O valor é %4.3f" %x)
print("O valor é %7.2f" %x)
print("O valor é %10f" %x)
print(" ")
print("x vale %f e y vale %f" %(x,y))
print("O valor é %.2f %s" %(x, unid))
print("O" + " valor" + " é " + str(x))
# Out:
# O valor é 3.14159 Hz
#
# O valor é 3.141590
# O valor é 3.141590
# O valor é 3.300000
#
# O valor é 3.142
# O valor é    3.14
# O valor é   3.141590
#
# x vale 3.141590 e y vale 3.300000
# O valor é 3.14 Hz
# O valor é 3.14159

# %% [markdown]
# ## f-String

# %%
nome = "Jones"
profissão = "Engenheiro"

print(f"Meu nome é {nome} e eu sou {profissão}.")

x = 2
print(f"O quadrado de {x} é {x**2}")
# Out:
# Meu nome é Jones e eu sou Engenheiro.
# O quadrado de 2 é 4

# %% [markdown]
# ## Entrada de dados

# %%
# Entrada de dados
x = input("Digite a variável 1: ")
y = input("Digite a variável 2: ")

print(x + y)
# Out:
# Digite a variável 1: 2
# Digite a variável 2: 3
# 23

# %%
# Entrada de números inteiros
x = int(input("Digite a variável 1: "))
y = int(input("Digite a variável 2: "))

print(x + y)
# Out:
# Digite a variável 1: 2
# Digite a variável 2: 3
# 5

# %%
# Entrada de números reais
x = float(input("Digite a variável 1: "))
y = float(input("Digite a variável 2: "))

print(x + y)
# Out:
# Digite a variável 1: 2.1
# Digite a variável 2: 3.2
# 5.300000000000001

# %% [markdown]
# ## Estrutura condicional

# %%
# Operadores lógicos
x = 5
y = 2

print(x == y)
print(x != y)
print(x > y)
print(x >= y)
print(x < y)
print(x <= y)
# Out:
# False
# True
# True
# True
# False
# False

# %% [markdown]
# ## Condicional

# %%
# Condicional "se"
print("Programa para cálculo das raízes de uma função polinomial do segundo grau")
a = int(input("Digite o valor de a: "))
b = int(input("Digite o valor de b: "))
c = int(input("Digite o valor de c: "))

delta = b**2 - 4*a*c

if delta > 0:
  x1 = (-b + delta**(1/2))/(2 * a)
  x2 = (-b + delta**(1/2))/(2 * a)
  print("Duas raízes reais distintas x1 = %.2f e x2 =%.2f" %(x1, x2))
elif delta == 0:
  x = (-b) /(2 * a)
  print("Duas raízes reais iguais x =%.2f" %x)
else:
  print("Não existem raízes reais.")
# Out:
# Programa para cálculo das raízes de uma função polinomial do segundo grau
# Digite o valor de a: 1
# Digite o valor de b: -1
# Digite o valor de c: -1
# Duas raízes reais distintas x1 = 1.62 e x2 =1.62

# %%
# While
contagem = 0
while (contagem < 9):
  print('A contagem é:', contagem)
  contagem = contagem + 1
print("Fim")
# Out:
# A contagem é: 0
# A contagem é: 1
# A contagem é: 2
# A contagem é: 3
# A contagem é: 4
# A contagem é: 5
# A contagem é: 6
# A contagem é: 7
# A contagem é: 8
# Fim

# %% [markdown]
# ## Funções

# %%
# Funções sem retorno de valor - código #1
print("\nVocê fez um bom trabalho, Huguinho!")
print("Muito obrigado por seus esforços neste projeto.")

print("\nVocê fez um bom trabalho, Zézinho")
print("Muito obrigado por seus esforços neste projeto.")

print("\nVocê fez um bom trabalho, Luizinho!")
print("Muito obrigado por seus esforços neste projeto.")
# Out:
# Você fez um bom trabalho, Huguinho!
# Muito obrigado por seus esforços neste projeto.
#
# Você fez um bom trabalho, Zézinho
# Muito obrigado por seus esforços neste projeto.
#
# Você fez um bom trabalho, Luizinho!
# Muito obrigado por seus esforços neste projeto.

# %%
# Funções sem retorno de valor - código #2
def obrigado(nome):
  #Esta função agradece a pessoa recebida como parâmetro.
  print("\nVocê fez um bom trabalho,%s!"% nome)
  print("Muito obrigado por seus esforços neste projeto.")

obrigado('Huguinho')
obrigado('Zézinho')
obrigado('Luizinho')
# Out:
# Você fez um bom trabalho,Huguinho!
# Muito obrigado por seus esforços neste projeto.
#
# Você fez um bom trabalho,Zézinho!
# Muito obrigado por seus esforços neste projeto.
#
# Você fez um bom trabalho,Luizinho!
# Muito obrigado por seus esforços neste projeto.

# %%
# Funções com retorno de valor
def retornaExtenso(numero):
  #Recebe um valor numérico e retorna seu valor por extenso
  if numero == 0:
    return 'zero'
  elif numero == 1:
    return 'um'
  elif numero == 2:
    return 'dois'
  elif numero == 3:
    return 'três'
  else:
    return "Desculpe me, eu não conheço este número."

#Programa principal
op = 'S'
while op == 'S':
  N = int(input("Digite um número: "))
  resposta = retornaExtenso(N)
  print(resposta)
  op = input("Deseja inserir outro número (S/N): ").upper()
# Out:
# Digite um número: 0
# zero
# Deseja inserir outro número (S/N): s
# Digite um número: 4
# Desculpe me, eu não conheço este número.
# Deseja inserir outro número (S/N): n

# %% [markdown]
# ## Listas

# %%
# Lista - exemplo
L = [7, "texto", True, 3.1416, ['outra lista', 18, 25]]

print(L[0])
print(L[2])
print(L[4])
print(L[-1])
print(L[-2])
print(L[-3])
print(L[4] [1])
print(L[4] [2])
print(L[0:2])
print(L[1:])
print(L[0:4:2])
print(L[::-1])
# Out:
# 7
# True
# ['outra lista', 18, 25]
# ['outra lista', 18, 25]
# 3.1416
# True
# 18
# 25
# [7, 'texto']
# ['texto', True, 3.1416, ['outra lista', 18, 25]]
# [7, True]
# [['outra lista', 18, 25], 3.1416, True, 'texto', 7]

# %%
# Exemplos de funções e métodos em listas
Lista = []
N  = int(input("Quantos elementos deseja digitar: "))
i = 0
while i < N:
    x = float(input("Digite o elemento %i: " %(i + 1)))
    Lista.append(x)
    i = i + 1

media = sum(Lista) / len(Lista)
Lista.sort()
if len(Lista)%2 == 0:
    mediana = (Lista[len(Lista)//2] + Lista[len(Lista)//2 - 1])/2
else:
    mediana = Lista[len(Lista)//2]
print("A média é %.2f e a mediana é %.2f." %(media, mediana))

Lista.clear()
# Out:
# Quantos elementos deseja digitar: 3
# Digite o elemento 1: 1
# Digite o elemento 2: 2
# Digite o elemento 3: 3
# A média é 2.00 e a mediana é 2.00.

# %%
# Cuidados ao copiar uma lista
lista_1 = [" banana"," maça", "laranja"]
lista_2 = lista_1
lista_2.pop()

print(lista_1)
print(lista_2)

#Isso sim é uma cópia
lista_1 = [" banana"," maça", "laranja"]
lista_2 = lista_1.copy() # list(lista1) ou listal[:]
lista_2.pop()

print(lista_1)
print(lista_2)
# Out:
# [' banana', ' maça']
# [' banana', ' maça']
# [' banana', ' maça', 'laranja']
# [' banana', ' maça']

# %% [markdown]
# ## Estrutura For

# %%
# Exemplo 1
for i in range (10):
    print('i =', i)

for letra in 'Python':
    print('Letra atual:', letra)

frutas = ['banana', 'maçã', 'manga']
for fruta in frutas:
    print('Fruta atual:', fruta)
# Out:
# i = 0
# i = 1
# i = 2
# i = 3
# i = 4
# i = 5
# i = 6
# i = 7
# i = 8
# i = 9
# Letra atual: P
# Letra atual: y
# Letra atual: t
# Letra atual: h
# Letra atual: o
# Letra atual: n
# Fruta atual: banana
# Fruta atual: maçã
# Fruta atual: manga

# %%
#Exemplo 2
x = [1, 2, 3, 4, 5]
x_2 = [i*i for i in x]
x_3 = [i*i for i in x if i%2 == 0]
x_4 = [i*i if i%2 == 0 else i for i in x]

print(x)
print(x_2)
print(x_3)
print(x_4)
# Out:
# [1, 2, 3, 4, 5]
# [1, 4, 9, 16, 25]
# [4, 16]
# [1, 4, 3, 16, 5]

# %% [markdown]
# ## Dicionários

# %%
#Exemplo
D = { 10 : True,
      "Um texto" : [42, 1.6],
      4.5 : 20,
     False : { 9 : 4, True : "algo" }
    }

print(D[10])
print(D["Um texto"])
print(D[False])
print(D[False] [9])
print(D[False][True])
# Out:
# True
# [42, 1.6]
# {9: 4, True: 'algo'}
# 4
# algo

# %% [markdown]
# ## Extra: web  scrapping

# %%
import webbrowser, sys, requests, bs4, json

CEP = input("Digite o CEP desejado: ")
res = requests.get('https://viacep.com.br/ws/'+ CEP + '/json/')
soup = bs4.BeautifulSoup(res.text, 'html.parser')
JSON_Datalist = soup.get_text()
dados = json.loads(JSON_Datalist)

if 'erro' in dados:
    print("CEP inválido.")
else:
    print('CEP: %s' % dados['cep'])
    print('Endereço: %s' % dados['logradouro'])
    print('Complemento: %s' % dados['complemento'])
    print('Bairro: %s' % dados['bairro'])
    print('Cidade: %s' % dados['localidade'])
    print('Estado: %s' % dados['uf'])
# Out:
# Digite o CEP desejado: 09580-900
# CEP: 09580-900
# Endereço: Praça Mauá
# Complemento: 01
# Bairro: Mauá
# Cidade: São Caetano do Sul
# Estado: SP
