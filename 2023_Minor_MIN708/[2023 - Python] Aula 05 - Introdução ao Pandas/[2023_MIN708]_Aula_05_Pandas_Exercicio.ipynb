# %% [markdown]
# # Introdução ao Pandas - Exercício

# %% [markdown]
# ## Importação de bibliotecas

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Lendo arquivos de dados: CSV

# %%
df_NetflixTitles = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/[2023 Minor]/[2023 - MIN708]/[2023.03.18] - Aula 05 - Pandas - Parte 01/_datasets/netflix_titles.csv")

# %%
print(df_NetflixTitles.shape)
# Out:
# (5850, 15)

# %%
print(df_NetflixTitles.columns)
# Out:
# Index(['id', 'title', 'type', 'description', 'release_year',
#        'age_certification', 'runtime', 'genres', 'production_countries',
#        'seasons', 'imdb_id', 'imdb_score', 'imdb_votes', 'tmdb_popularity',
#        'tmdb_score'],
#       dtype='object')

# %%
df_NetflixTitles.head(5)
# Out:
#          id                                title   type  \
# 0  ts300399  Five Came Back: The Reference Films   SHOW
# 1   tm84618                          Taxi Driver  MOVIE
# 2  tm154986                          Deliverance  MOVIE
# 3  tm127384      Monty Python and the Holy Grail  MOVIE
# 4  tm120801                      The Dirty Dozen  MOVIE
#
#                                          description  release_year  \
# 0  This collection includes 12 World War II-era p...          1945
# 1  A mentally unstable Vietnam War veteran works ...          1976
# 2  Intent on seeing the Cahulawassee River before...          1972
# 3  King Arthur, accompanied by his squire, recrui...          1975
# 4  12 American military prisoners in World War II...          1967
#
#   age_certification  runtime                                       genres  \
# 0             TV-MA       51                            ['documentation']
# ...

# %% [markdown]
# ## Seleção e indexação

# %%
df_NetflixTitles["type"]
# Out:
# 0        SHOW
# 1       MOVIE
# 2       MOVIE
# 3       MOVIE
# 4       MOVIE
#         ...
# 5845    MOVIE
# 5846    MOVIE
# 5847    MOVIE
# 5848    MOVIE
# 5849     SHOW
# Name: type, Length: 5850, dtype: object

# %%
df_NetflixTitles.type[0]
# Out:
# 'SHOW'

# %%
df_NetflixTitles.iloc[0]
# Out:
# id                                                               ts300399
# title                                 Five Came Back: The Reference Films
# type                                                                 SHOW
# description             This collection includes 12 World War II-era p...
# release_year                                                         1945
# age_certification                                                   TV-MA
# runtime                                                                51
# genres                                                  ['documentation']
# production_countries                                               ['US']
# seasons                                                               1.0
# imdb_id                                                               NaN
# imdb_score                                                            NaN
# imdb_votes                                                            NaN
# ...

# %%
df_NetflixTitles.iloc[:,0]
# Out:
# 0        ts300399
# 1         tm84618
# 2        tm154986
# 3        tm127384
# 4        tm120801
#           ...
# 5845    tm1014599
# 5846     tm898842
# 5847    tm1059008
# 5848    tm1035612
# 5849     ts271048
# Name: id, Length: 5850, dtype: object

# %%
df_NetflixTitles.loc[0]
# Out:
# id                                                               ts300399
# title                                 Five Came Back: The Reference Films
# type                                                                 SHOW
# description             This collection includes 12 World War II-era p...
# release_year                                                         1945
# age_certification                                                   TV-MA
# runtime                                                                51
# genres                                                  ['documentation']
# production_countries                                               ['US']
# seasons                                                               1.0
# imdb_id                                                               NaN
# imdb_score                                                            NaN
# imdb_votes                                                            NaN
# ...

# %%
df_NetflixTitles.loc[1:3]
# Out:
#          id                            title   type  \
# 1   tm84618                      Taxi Driver  MOVIE
# 2  tm154986                      Deliverance  MOVIE
# 3  tm127384  Monty Python and the Holy Grail  MOVIE
#
#                                          description  release_year  \
# 1  A mentally unstable Vietnam War veteran works ...          1976
# 2  Intent on seeing the Cahulawassee River before...          1972
# 3  King Arthur, accompanied by his squire, recrui...          1975
#
#   age_certification  runtime                                       genres  \
# 1                 R      114                           ['drama', 'crime']
# 2                 R      109  ['drama', 'action', 'thriller', 'european']
# 3                PG       91              ['fantasy', 'action', 'comedy']
#
#   production_countries  seasons    imdb_id  imdb_score  imdb_votes  \
# 1               ['US']      NaN  tt0075314         8.2    808582.0
# ...

# %%
df_NetflixTitles.loc[0, 'release_year']
# Out:
# 1945

# %%
df_NetflixTitles.loc[1, 'release_year']
# Out:
# 1976

# %%
df_NetflixTitles.loc[df_NetflixTitles.release_year > 2019]
# Out:
#              id                                      title   type  \
# 3043   ts216746             The Secret of Skinwalker Ranch   SHOW
# 3052   ts254656            Jurassic World: Camp Cretaceous   SHOW
# 3054   ts216679                                 Bridgerton   SHOW
# 3055   ts237109                                  Control Z   SHOW
# 3061    ts89259                         The Queen's Gambit   SHOW
# ...         ...                                        ...    ...
# 5845  tm1014599                                  Fine Wine  MOVIE
# 5846   tm898842                                C/O Kaadhal  MOVIE
# 5847  tm1059008                                    Lokillo  MOVIE
# 5848  tm1035612  Dad Stop Embarrassing Me - The Afterparty  MOVIE
# 5849   ts271048         Mighty Little Bheem: Kite Festival   SHOW
#
#                                             description  release_year  \
# 3043  A team of experts and scientists undertakes ex...          2020
# ...

# %%
df_NetflixTitles.loc[(df_NetflixTitles.release_year > 2019) & (df_NetflixTitles.type == "MOVIE")]
# Out:
#              id                                      title   type  \
# 3072   tm681578                                 The Rental  MOVIE
# 3075   tm369594              I'm Thinking of Ending Things  MOVIE
# 3082   tm496322                                 Extraction  MOVIE
# 3084   tm863808                         My Octopus Teacher  MOVIE
# 3087   tm460124                              Yes, God, Yes  MOVIE
# ...         ...                                        ...    ...
# 5844  tm1074617              Bling Empire - The Afterparty  MOVIE
# 5845  tm1014599                                  Fine Wine  MOVIE
# 5846   tm898842                                C/O Kaadhal  MOVIE
# 5847  tm1059008                                    Lokillo  MOVIE
# 5848  tm1035612  Dad Stop Embarrassing Me - The Afterparty  MOVIE
#
#                                             description  release_year  \
# 3072  Two couples rent a vacation home for what shou...          2020
# ...

# %%
df_NetflixTitles.loc[df_NetflixTitles.release_year.isin([2019, 2020])]
# Out:
#             id                                          title   type  \
# 3042   ts76645                           The Umbrella Academy   SHOW
# 3043  ts216746                 The Secret of Skinwalker Ranch   SHOW
# 3044   ts89840                                   Virgin River   SHOW
# 3045  tm441050                                  The Gentlemen  MOVIE
# 3046   ts87466                 Demon Slayer: Kimetsu no Yaiba   SHOW
# ...        ...                                            ...    ...
# 4687  tm981675  Super Monsters: Santa's Super Monster Helpers  MOVIE
# 4688  ts222362                    Mighty Little Bheem: Diwali   SHOW
# 4689  tm460199                             High End Yaariyaan  MOVIE
# 4690  tm463814                   Edoardo Ferrario: Temi Caldi  MOVIE
# 4691  ts224956                What the Love! with Karan Johar   SHOW
#
#                                             description  release_year  \
# ...

# %%
df_NetflixTitles.set_index("release_year")
# Out:
#                      id                                      title   type  \
# release_year
# 1945           ts300399        Five Came Back: The Reference Films   SHOW
# 1976            tm84618                                Taxi Driver  MOVIE
# 1972           tm154986                                Deliverance  MOVIE
# 1975           tm127384            Monty Python and the Holy Grail  MOVIE
# 1967           tm120801                            The Dirty Dozen  MOVIE
# ...                 ...                                        ...    ...
# 2021          tm1014599                                  Fine Wine  MOVIE
# 2021           tm898842                                C/O Kaadhal  MOVIE
# 2021          tm1059008                                    Lokillo  MOVIE
# 2021          tm1035612  Dad Stop Embarrassing Me - The Afterparty  MOVIE
# 2021           ts271048         Mighty Little Bheem: Kite Festival   SHOW
#
# ...

# %% [markdown]
# ## Exercícios
#
# ![ScreenHunter 3267.png](data:image/png;base64,...)

# %% [markdown]
# #### E01

# %%
# Resposta

# %% [markdown]
# #### E02

# %%
# Resposta

# %% [markdown]
# #### E03

# %%
# Resposta

# %% [markdown]
# #### E04

# %%
# Resposta

# %% [markdown]
# #### E05

# %%
# Resposta

# %% [markdown]
# #### E06

# %%
# Resposta

# %% [markdown]
# #### E07

# %%
# Resposta

# %% [markdown]
# #### E08

# %%
# Resposta

# %% [markdown]
# #### E09

# %%
# Resposta
