# %% [markdown]
# # Exemplos utilizando o Módulo Turtle

# %% [markdown]
# ## Importação de bibliotecas

# %%
# !pip3 install ColabTurtle
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for ColabTurtle: filename=ColabTurtle-2.1.0-py3-none-any.whl size=7656 sha256=1a7c1133f4b6acbc89af4487518d9bbc25643834fe9f898173f709e17dfa7b41
#   Stored in directory: /root/.cache/pip/wheels/a9/85/dc/29b6b43c4c6c0fe37192ccad65fe2adcef1e52dd24b0eb61fc
# Successfully built ColabTurtle
# ...

# %%
from ColabTurtle.Turtle import *
#import ColabTurtle.Turtle

# %% [markdown]
# ## Comandos

# %%
#Cria janela para o desenho
initializeTurtle(initial_speed=5)
# Out:
#       <svg width="800" height="500">
#         <rect width="100%" height="100%" fill="black"/>
#
#         <g visibility=visible transform="rotate(360,400,250) translate(382, 232)">
# ...

# %%
#Comandos para direção da tartaruga
forward(100)
left(90)
forward(100)
left(90)
forward(100)
left(90)
forward(100)
# Out:
#       <svg width="800" height="500">
#         <rect width="100%" height="100%" fill="black"/>
#         <line x1="400" y1="250" x2="400.0" y2="150.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="400.0" y1="150.0" x2="300.0" y2="150.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="300.0" y1="150.0" x2="300.0" y2="250.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="300.0" y1="250.0" x2="400.0" y2="250.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="400.0" y1="250.0" x2="500.0" y2="250.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="500.0" y1="250.0" x2="500.0" y2="150.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="500.0" y1="150.0" x2="400.0" y2="150.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="400.0" y1="150.0" x2="400.0" y2="250.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/>
# ...

# %%
#Cria janela para o desenho
initializeTurtle(initial_speed=5)

#Comandos para direção da tartaruga
for _ in range(4):
  forward(200)
  left(90)
# Out:
#       <svg width="800" height="500">
#         <rect width="100%" height="100%" fill="black"/>
#         <line x1="400" y1="250" x2="400.0" y2="50.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="400.0" y1="50.0" x2="200.0" y2="50.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="200.0" y1="50.0" x2="200.0" y2="250.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="200.0" y1="250.0" x2="400.0" y2="250.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/>
#         <g visibility=visible transform="rotate(360,400.0,250.0) translate(382.0, 232.0)">
# ...
